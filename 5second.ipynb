# %%
import os
import librosa
import soundfile as sf
import numpy as np

def get_wav_files(folder_path):
    return [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.WAV')]

def split_audio_files(audio_files, output_folder, chunk_duration=5, sr=44100):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for audio_file in audio_files:
        print(f'Processing {audio_file}...')
        y, sr = librosa.load(audio_file, sr=sr)
        
        # Calculate the number of samples per chunk
        chunk_samples = chunk_duration * sr
        
        # Split the audio into chunks
        for i in range(0, len(y), chunk_samples):
            chunk = y[i:i + chunk_samples]
            
            # Ensure the chunk is exactly 5 seconds long
            if len(chunk) < chunk_samples:
                chunk = np.pad(chunk, (0, chunk_samples - len(chunk)), mode='constant')
            
            # Create a new filename for the chunk
            base, ext = os.path.splitext(os.path.basename(audio_file))
            chunk_filename = f"{base}_chunk{i // chunk_samples}{ext}"
            chunk_path = os.path.join(output_folder, chunk_filename)
            
            # Save the chunk as a new audio file
            sf.write(chunk_path, chunk, sr)
            print(f'Saved chunk: {chunk_filename}')

# Example usage
folder_path = 'Gunshots Garth/R4 Recorder'  # Folder containing the audio files
output_folder1 = 'output_chunks1'  # Folder to save the chunks

audio_files = get_wav_files(folder_path)
split_audio_files(audio_files, output_folder1)
# Out:
# Processing Gunshots Garth/R4 Recorder\R4_00061.WAV...
# Saved chunk: R4_00061_chunk0.WAV
# Saved chunk: R4_00061_chunk1.WAV
# Saved chunk: R4_00061_chunk2.WAV
# Saved chunk: R4_00061_chunk3.WAV
# Saved chunk: R4_00061_chunk4.WAV
# Saved chunk: R4_00061_chunk5.WAV
# Saved chunk: R4_00061_chunk6.WAV
# Saved chunk: R4_00061_chunk7.WAV
# Saved chunk: R4_00061_chunk8.WAV
# Saved chunk: R4_00061_chunk9.WAV
# Saved chunk: R4_00061_chunk10.WAV
# Saved chunk: R4_00061_chunk11.WAV
# Processing Gunshots Garth/R4 Recorder\R4_00062.WAV...
# Saved chunk: R4_00062_chunk0.WAV
# Saved chunk: R4_00062_chunk1.WAV
# Saved chunk: R4_00062_chunk2.WAV
# Saved chunk: R4_00062_chunk3.WAV
# Saved chunk: R4_00062_chunk4.WAV
# Saved chunk: R4_00062_chunk5.WAV
# Saved chunk: R4_00062_chunk6.WAV
# Saved chunk: R4_00062_chunk7.WAV
# Saved chunk: R4_00062_chunk8.WAV
# Saved chunk: R4_00062_chunk9.WAV
# Saved chunk: R4_00062_chunk10.WAV
# Saved chunk: R4_00062_chunk11.WAV
# Saved chunk: R4_00062_chunk12.WAV
# Saved chunk: R4_00062_chunk13.WAV
# Saved chunk: R4_00062_chunk14.WAV
# Saved chunk: R4_00062_chunk15.WAV
# Saved chunk: R4_00062_chunk16.WAV
# Saved chunk: R4_00062_chunk17.WAV
# Saved chunk: R4_00062_chunk18.WAV
# Saved chunk: R4_00062_chunk19.WAV
# Saved chunk: R4_00062_chunk20.WAV
# Saved chunk: R4_00062_chunk21.WAV
# Saved chunk: R4_00062_chunk22.WAV
# Saved chunk: R4_00062_chunk23.WAV
# Saved chunk: R4_00062_chunk24.WAV
# Saved chunk: R4_00062_chunk25.WAV
# Saved chunk: R4_00062_chunk26.WAV
# Saved chunk: R4_00062_chunk27.WAV
# Saved chunk: R4_00062_chunk28.WAV
# Saved chunk: R4_00062_chunk29.WAV
# Saved chunk: R4_00062_chunk30.WAV
# Saved chunk: R4_00062_chunk31.WAV
# Saved chunk: R4_00062_chunk32.WAV
# Saved chunk: R4_00062_chunk33.WAV
# Saved chunk: R4_00062_chunk34.WAV
# Saved chunk: R4_00062_chunk35.WAV
# Saved chunk: R4_00062_chunk36.WAV
# Saved chunk: R4_00062_chunk37.WAV
# Saved chunk: R4_00062_chunk38.WAV
# Saved chunk: R4_00062_chunk39.WAV
# Saved chunk: R4_00062_chunk40.WAV
# Saved chunk: R4_00062_chunk41.WAV
# Saved chunk: R4_00062_chunk42.WAV
# Saved chunk: R4_00062_chunk43.WAV
# Saved chunk: R4_00062_chunk44.WAV
# Saved chunk: R4_00062_chunk45.WAV
# Saved chunk: R4_00062_chunk46.WAV
# Saved chunk: R4_00062_chunk47.WAV
# Saved chunk: R4_00062_chunk48.WAV
# Saved chunk: R4_00062_chunk49.WAV
# Saved chunk: R4_00062_chunk50.WAV
# Saved chunk: R4_00062_chunk51.WAV
# Saved chunk: R4_00062_chunk52.WAV
# Saved chunk: R4_00062_chunk53.WAV
# Saved chunk: R4_00062_chunk54.WAV
# Saved chunk: R4_00062_chunk55.WAV
# Saved chunk: R4_00062_chunk56.WAV
# Saved chunk: R4_00062_chunk57.WAV
# Saved chunk: R4_00062_chunk58.WAV
# Saved chunk: R4_00062_chunk59.WAV
# Saved chunk: R4_00062_chunk60.WAV
# Saved chunk: R4_00062_chunk61.WAV
# Saved chunk: R4_00062_chunk62.WAV
# Saved chunk: R4_00062_chunk63.WAV
# Saved chunk: R4_00062_chunk64.WAV
# Saved chunk: R4_00062_chunk65.WAV
# Saved chunk: R4_00062_chunk66.WAV
# Saved chunk: R4_00062_chunk67.WAV
# Saved chunk: R4_00062_chunk68.WAV
# Saved chunk: R4_00062_chunk69.WAV
# Saved chunk: R4_00062_chunk70.WAV
# Saved chunk: R4_00062_chunk71.WAV
# Saved chunk: R4_00062_chunk72.WAV
# Saved chunk: R4_00062_chunk73.WAV
# Saved chunk: R4_00062_chunk74.WAV
# Saved chunk: R4_00062_chunk75.WAV
# Saved chunk: R4_00062_chunk76.WAV
# Saved chunk: R4_00062_chunk77.WAV
# Saved chunk: R4_00062_chunk78.WAV
# Saved chunk: R4_00062_chunk79.WAV
# Saved chunk: R4_00062_chunk80.WAV
# Saved chunk: R4_00062_chunk81.WAV
# Saved chunk: R4_00062_chunk82.WAV
# Saved chunk: R4_00062_chunk83.WAV
# Saved chunk: R4_00062_chunk84.WAV
# Saved chunk: R4_00062_chunk85.WAV
# Saved chunk: R4_00062_chunk86.WAV
# Saved chunk: R4_00062_chunk87.WAV
# Saved chunk: R4_00062_chunk88.WAV
# Saved chunk: R4_00062_chunk89.WAV
# Saved chunk: R4_00062_chunk90.WAV
# Saved chunk: R4_00062_chunk91.WAV
# Saved chunk: R4_00062_chunk92.WAV
# Saved chunk: R4_00062_chunk93.WAV
# Saved chunk: R4_00062_chunk94.WAV
# Saved chunk: R4_00062_chunk95.WAV
# Saved chunk: R4_00062_chunk96.WAV
# Saved chunk: R4_00062_chunk97.WAV
# Saved chunk: R4_00062_chunk98.WAV
# Saved chunk: R4_00062_chunk99.WAV
# Saved chunk: R4_00062_chunk100.WAV
# Saved chunk: R4_00062_chunk101.WAV
# Saved chunk: R4_00062_chunk102.WAV
# Saved chunk: R4_00062_chunk103.WAV
# Saved chunk: R4_00062_chunk104.WAV
# Saved chunk: R4_00062_chunk105.WAV
# Saved chunk: R4_00062_chunk106.WAV
# Saved chunk: R4_00062_chunk107.WAV
# Saved chunk: R4_00062_chunk108.WAV
# Saved chunk: R4_00062_chunk109.WAV
# Saved chunk: R4_00062_chunk110.WAV
# Saved chunk: R4_00062_chunk111.WAV
# Saved chunk: R4_00062_chunk112.WAV
# Saved chunk: R4_00062_chunk113.WAV
# Saved chunk: R4_00062_chunk114.WAV
# Saved chunk: R4_00062_chunk115.WAV
# Saved chunk: R4_00062_chunk116.WAV
# Saved chunk: R4_00062_chunk117.WAV
# Saved chunk: R4_00062_chunk118.WAV
# Saved chunk: R4_00062_chunk119.WAV
# Saved chunk: R4_00062_chunk120.WAV
# Saved chunk: R4_00062_chunk121.WAV
# Saved chunk: R4_00062_chunk122.WAV
# Saved chunk: R4_00062_chunk123.WAV
# Saved chunk: R4_00062_chunk124.WAV
# Saved chunk: R4_00062_chunk125.WAV
# Saved chunk: R4_00062_chunk126.WAV
# Saved chunk: R4_00062_chunk127.WAV
# Saved chunk: R4_00062_chunk128.WAV
# Saved chunk: R4_00062_chunk129.WAV
# Saved chunk: R4_00062_chunk130.WAV
# Saved chunk: R4_00062_chunk131.WAV
# Saved chunk: R4_00062_chunk132.WAV
# Saved chunk: R4_00062_chunk133.WAV
# Saved chunk: R4_00062_chunk134.WAV
# Saved chunk: R4_00062_chunk135.WAV
# Saved chunk: R4_00062_chunk136.WAV
# Saved chunk: R4_00062_chunk137.WAV
# Saved chunk: R4_00062_chunk138.WAV
# Saved chunk: R4_00062_chunk139.WAV
# Saved chunk: R4_00062_chunk140.WAV
# Saved chunk: R4_00062_chunk141.WAV
# Saved chunk: R4_00062_chunk142.WAV
# Saved chunk: R4_00062_chunk143.WAV
# Saved chunk: R4_00062_chunk144.WAV
# Saved chunk: R4_00062_chunk145.WAV
# Saved chunk: R4_00062_chunk146.WAV
# Saved chunk: R4_00062_chunk147.WAV
# Saved chunk: R4_00062_chunk148.WAV
# Saved chunk: R4_00062_chunk149.WAV
# Saved chunk: R4_00062_chunk150.WAV
# Saved chunk: R4_00062_chunk151.WAV
# Saved chunk: R4_00062_chunk152.WAV
# Saved chunk: R4_00062_chunk153.WAV
# Saved chunk: R4_00062_chunk154.WAV
# Saved chunk: R4_00062_chunk155.WAV
# Saved chunk: R4_00062_chunk156.WAV
# Saved chunk: R4_00062_chunk157.WAV
# Saved chunk: R4_00062_chunk158.WAV
# Saved chunk: R4_00062_chunk159.WAV
# Saved chunk: R4_00062_chunk160.WAV
# Saved chunk: R4_00062_chunk161.WAV
# Saved chunk: R4_00062_chunk162.WAV
# Saved chunk: R4_00062_chunk163.WAV
# Saved chunk: R4_00062_chunk164.WAV
# Saved chunk: R4_00062_chunk165.WAV
# Saved chunk: R4_00062_chunk166.WAV
# Saved chunk: R4_00062_chunk167.WAV
# Saved chunk: R4_00062_chunk168.WAV
# Saved chunk: R4_00062_chunk169.WAV
# Saved chunk: R4_00062_chunk170.WAV
# Saved chunk: R4_00062_chunk171.WAV
# Saved chunk: R4_00062_chunk172.WAV
# Saved chunk: R4_00062_chunk173.WAV
# Saved chunk: R4_00062_chunk174.WAV
# Saved chunk: R4_00062_chunk175.WAV
# Saved chunk: R4_00062_chunk176.WAV
# Saved chunk: R4_00062_chunk177.WAV
# Saved chunk: R4_00062_chunk178.WAV
# Saved chunk: R4_00062_chunk179.WAV
# Saved chunk: R4_00062_chunk180.WAV
# Saved chunk: R4_00062_chunk181.WAV
# Saved chunk: R4_00062_chunk182.WAV
# Saved chunk: R4_00062_chunk183.WAV
# Saved chunk: R4_00062_chunk184.WAV
# Saved chunk: R4_00062_chunk185.WAV
# Saved chunk: R4_00062_chunk186.WAV
# Saved chunk: R4_00062_chunk187.WAV
# Saved chunk: R4_00062_chunk188.WAV
# Saved chunk: R4_00062_chunk189.WAV
# Saved chunk: R4_00062_chunk190.WAV
# Saved chunk: R4_00062_chunk191.WAV
# Saved chunk: R4_00062_chunk192.WAV
# Saved chunk: R4_00062_chunk193.WAV
# Saved chunk: R4_00062_chunk194.WAV
# Saved chunk: R4_00062_chunk195.WAV
# Saved chunk: R4_00062_chunk196.WAV
# Saved chunk: R4_00062_chunk197.WAV
# Saved chunk: R4_00062_chunk198.WAV
# Saved chunk: R4_00062_chunk199.WAV
# Saved chunk: R4_00062_chunk200.WAV
# Saved chunk: R4_00062_chunk201.WAV
# Saved chunk: R4_00062_chunk202.WAV
# Saved chunk: R4_00062_chunk203.WAV
# Saved chunk: R4_00062_chunk204.WAV
# Saved chunk: R4_00062_chunk205.WAV
# Saved chunk: R4_00062_chunk206.WAV
# Saved chunk: R4_00062_chunk207.WAV
# Saved chunk: R4_00062_chunk208.WAV
# Saved chunk: R4_00062_chunk209.WAV
# Saved chunk: R4_00062_chunk210.WAV
# Saved chunk: R4_00062_chunk211.WAV
# Saved chunk: R4_00062_chunk212.WAV
# Saved chunk: R4_00062_chunk213.WAV
# Saved chunk: R4_00062_chunk214.WAV
# Saved chunk: R4_00062_chunk215.WAV
# Saved chunk: R4_00062_chunk216.WAV
# Saved chunk: R4_00062_chunk217.WAV
# Saved chunk: R4_00062_chunk218.WAV
# Saved chunk: R4_00062_chunk219.WAV
# Saved chunk: R4_00062_chunk220.WAV
# Saved chunk: R4_00062_chunk221.WAV
# Saved chunk: R4_00062_chunk222.WAV
# Saved chunk: R4_00062_chunk223.WAV
# Saved chunk: R4_00062_chunk224.WAV
# Saved chunk: R4_00062_chunk225.WAV
# Saved chunk: R4_00062_chunk226.WAV
# Saved chunk: R4_00062_chunk227.WAV
# Saved chunk: R4_00062_chunk228.WAV
# Saved chunk: R4_00062_chunk229.WAV
# Saved chunk: R4_00062_chunk230.WAV
# Saved chunk: R4_00062_chunk231.WAV
# Processing Gunshots Garth/R4 Recorder\R4_00063.WAV...
# Saved chunk: R4_00063_chunk0.WAV
# Saved chunk: R4_00063_chunk1.WAV
# Saved chunk: R4_00063_chunk2.WAV
# Saved chunk: R4_00063_chunk3.WAV
# Saved chunk: R4_00063_chunk4.WAV
# Saved chunk: R4_00063_chunk5.WAV
# Saved chunk: R4_00063_chunk6.WAV
# Saved chunk: R4_00063_chunk7.WAV
# Saved chunk: R4_00063_chunk8.WAV
# Saved chunk: R4_00063_chunk9.WAV
# Saved chunk: R4_00063_chunk10.WAV
# Saved chunk: R4_00063_chunk11.WAV
# Saved chunk: R4_00063_chunk12.WAV
# Saved chunk: R4_00063_chunk13.WAV
# Saved chunk: R4_00063_chunk14.WAV
# Saved chunk: R4_00063_chunk15.WAV
# Saved chunk: R4_00063_chunk16.WAV
# Saved chunk: R4_00063_chunk17.WAV
# Saved chunk: R4_00063_chunk18.WAV
# Saved chunk: R4_00063_chunk19.WAV
# Saved chunk: R4_00063_chunk20.WAV
# Saved chunk: R4_00063_chunk21.WAV
# Saved chunk: R4_00063_chunk22.WAV
# Saved chunk: R4_00063_chunk23.WAV
# Saved chunk: R4_00063_chunk24.WAV
# Saved chunk: R4_00063_chunk25.WAV
# Saved chunk: R4_00063_chunk26.WAV
# Saved chunk: R4_00063_chunk27.WAV
# Saved chunk: R4_00063_chunk28.WAV
# Saved chunk: R4_00063_chunk29.WAV
# Saved chunk: R4_00063_chunk30.WAV
# Saved chunk: R4_00063_chunk31.WAV
# Saved chunk: R4_00063_chunk32.WAV
# Saved chunk: R4_00063_chunk33.WAV
# Saved chunk: R4_00063_chunk34.WAV
# Saved chunk: R4_00063_chunk35.WAV
# Saved chunk: R4_00063_chunk36.WAV
# Saved chunk: R4_00063_chunk37.WAV
# Saved chunk: R4_00063_chunk38.WAV
# Saved chunk: R4_00063_chunk39.WAV
# Saved chunk: R4_00063_chunk40.WAV
# Saved chunk: R4_00063_chunk41.WAV
# Saved chunk: R4_00063_chunk42.WAV
# Saved chunk: R4_00063_chunk43.WAV
# Saved chunk: R4_00063_chunk44.WAV
# Saved chunk: R4_00063_chunk45.WAV
# Saved chunk: R4_00063_chunk46.WAV
# Saved chunk: R4_00063_chunk47.WAV
# Saved chunk: R4_00063_chunk48.WAV
# Saved chunk: R4_00063_chunk49.WAV
# Saved chunk: R4_00063_chunk50.WAV
# Saved chunk: R4_00063_chunk51.WAV
# Saved chunk: R4_00063_chunk52.WAV
# Saved chunk: R4_00063_chunk53.WAV
# Saved chunk: R4_00063_chunk54.WAV
# Saved chunk: R4_00063_chunk55.WAV
# Processing Gunshots Garth/R4 Recorder\R4_00064.WAV...
# Saved chunk: R4_00064_chunk0.WAV
# Saved chunk: R4_00064_chunk1.WAV
# Saved chunk: R4_00064_chunk2.WAV
# Saved chunk: R4_00064_chunk3.WAV
# Saved chunk: R4_00064_chunk4.WAV
# Saved chunk: R4_00064_chunk5.WAV
# Saved chunk: R4_00064_chunk6.WAV
# Saved chunk: R4_00064_chunk7.WAV
# Saved chunk: R4_00064_chunk8.WAV
# Saved chunk: R4_00064_chunk9.WAV
# Saved chunk: R4_00064_chunk10.WAV
# Saved chunk: R4_00064_chunk11.WAV
# Saved chunk: R4_00064_chunk12.WAV
# Saved chunk: R4_00064_chunk13.WAV
# Saved chunk: R4_00064_chunk14.WAV
# Saved chunk: R4_00064_chunk15.WAV
# Saved chunk: R4_00064_chunk16.WAV
# Saved chunk: R4_00064_chunk17.WAV
# Saved chunk: R4_00064_chunk18.WAV
# Saved chunk: R4_00064_chunk19.WAV
# Saved chunk: R4_00064_chunk20.WAV
# Saved chunk: R4_00064_chunk21.WAV
# Saved chunk: R4_00064_chunk22.WAV
# Saved chunk: R4_00064_chunk23.WAV
# Saved chunk: R4_00064_chunk24.WAV
# Saved chunk: R4_00064_chunk25.WAV
# Saved chunk: R4_00064_chunk26.WAV
# Saved chunk: R4_00064_chunk27.WAV
# Saved chunk: R4_00064_chunk28.WAV
# Saved chunk: R4_00064_chunk29.WAV
# Saved chunk: R4_00064_chunk30.WAV
# Saved chunk: R4_00064_chunk31.WAV
# Saved chunk: R4_00064_chunk32.WAV
# Saved chunk: R4_00064_chunk33.WAV
# Saved chunk: R4_00064_chunk34.WAV
# Saved chunk: R4_00064_chunk35.WAV
# Saved chunk: R4_00064_chunk36.WAV
# Saved chunk: R4_00064_chunk37.WAV
# Saved chunk: R4_00064_chunk38.WAV
# Saved chunk: R4_00064_chunk39.WAV
# Saved chunk: R4_00064_chunk40.WAV
# Saved chunk: R4_00064_chunk41.WAV
# Saved chunk: R4_00064_chunk42.WAV
# Saved chunk: R4_00064_chunk43.WAV
# Saved chunk: R4_00064_chunk44.WAV
# Saved chunk: R4_00064_chunk45.WAV
# Saved chunk: R4_00064_chunk46.WAV
# Saved chunk: R4_00064_chunk47.WAV
# Saved chunk: R4_00064_chunk48.WAV
# Saved chunk: R4_00064_chunk49.WAV
# Saved chunk: R4_00064_chunk50.WAV
# Saved chunk: R4_00064_chunk51.WAV
# Saved chunk: R4_00064_chunk52.WAV
# Saved chunk: R4_00064_chunk53.WAV
# Saved chunk: R4_00064_chunk54.WAV
# Saved chunk: R4_00064_chunk55.WAV
# Saved chunk: R4_00064_chunk56.WAV
# Saved chunk: R4_00064_chunk57.WAV
# Saved chunk: R4_00064_chunk58.WAV
# Saved chunk: R4_00064_chunk59.WAV
# Saved chunk: R4_00064_chunk60.WAV
# Saved chunk: R4_00064_chunk61.WAV
# Saved chunk: R4_00064_chunk62.WAV
# Saved chunk: R4_00064_chunk63.WAV
# Saved chunk: R4_00064_chunk64.WAV
# Saved chunk: R4_00064_chunk65.WAV
# Saved chunk: R4_00064_chunk66.WAV
# Saved chunk: R4_00064_chunk67.WAV
# Saved chunk: R4_00064_chunk68.WAV
# Saved chunk: R4_00064_chunk69.WAV
# Saved chunk: R4_00064_chunk70.WAV
# Saved chunk: R4_00064_chunk71.WAV
# Saved chunk: R4_00064_chunk72.WAV
# Saved chunk: R4_00064_chunk73.WAV
# Saved chunk: R4_00064_chunk74.WAV
# Saved chunk: R4_00064_chunk75.WAV
# Saved chunk: R4_00064_chunk76.WAV
# Saved chunk: R4_00064_chunk77.WAV
# Saved chunk: R4_00064_chunk78.WAV
# Saved chunk: R4_00064_chunk79.WAV
# Saved chunk: R4_00064_chunk80.WAV
# Saved chunk: R4_00064_chunk81.WAV
# Saved chunk: R4_00064_chunk82.WAV
# Saved chunk: R4_00064_chunk83.WAV
# Saved chunk: R4_00064_chunk84.WAV
# Saved chunk: R4_00064_chunk85.WAV
# Saved chunk: R4_00064_chunk86.WAV
# Saved chunk: R4_00064_chunk87.WAV
# Saved chunk: R4_00064_chunk88.WAV
# Saved chunk: R4_00064_chunk89.WAV
# Saved chunk: R4_00064_chunk90.WAV
# Saved chunk: R4_00064_chunk91.WAV
# Saved chunk: R4_00064_chunk92.WAV
# Saved chunk: R4_00064_chunk93.WAV
# Saved chunk: R4_00064_chunk94.WAV
# Saved chunk: R4_00064_chunk95.WAV
# Saved chunk: R4_00064_chunk96.WAV
# Saved chunk: R4_00064_chunk97.WAV
# Saved chunk: R4_00064_chunk98.WAV
# Saved chunk: R4_00064_chunk99.WAV
# Saved chunk: R4_00064_chunk100.WAV
# Saved chunk: R4_00064_chunk101.WAV
# Saved chunk: R4_00064_chunk102.WAV
# Saved chunk: R4_00064_chunk103.WAV
# Saved chunk: R4_00064_chunk104.WAV
# Saved chunk: R4_00064_chunk105.WAV
# Saved chunk: R4_00064_chunk106.WAV
# Saved chunk: R4_00064_chunk107.WAV
# Saved chunk: R4_00064_chunk108.WAV
# Saved chunk: R4_00064_chunk109.WAV
# Saved chunk: R4_00064_chunk110.WAV
# Saved chunk: R4_00064_chunk111.WAV
# Saved chunk: R4_00064_chunk112.WAV
# Saved chunk: R4_00064_chunk113.WAV
# Saved chunk: R4_00064_chunk114.WAV
# Saved chunk: R4_00064_chunk115.WAV
# Saved chunk: R4_00064_chunk116.WAV
# Saved chunk: R4_00064_chunk117.WAV
# Saved chunk: R4_00064_chunk118.WAV
# Saved chunk: R4_00064_chunk119.WAV
# Saved chunk: R4_00064_chunk120.WAV
# Saved chunk: R4_00064_chunk121.WAV
# Saved chunk: R4_00064_chunk122.WAV
# Saved chunk: R4_00064_chunk123.WAV
# Saved chunk: R4_00064_chunk124.WAV
# Saved chunk: R4_00064_chunk125.WAV
# Saved chunk: R4_00064_chunk126.WAV
# Saved chunk: R4_00064_chunk127.WAV
# Saved chunk: R4_00064_chunk128.WAV
# Saved chunk: R4_00064_chunk129.WAV
# Saved chunk: R4_00064_chunk130.WAV
# Saved chunk: R4_00064_chunk131.WAV
# Saved chunk: R4_00064_chunk132.WAV
# Saved chunk: R4_00064_chunk133.WAV
# Saved chunk: R4_00064_chunk134.WAV
# Saved chunk: R4_00064_chunk135.WAV
# Saved chunk: R4_00064_chunk136.WAV
# Saved chunk: R4_00064_chunk137.WAV
# Saved chunk: R4_00064_chunk138.WAV
# Saved chunk: R4_00064_chunk139.WAV
# Saved chunk: R4_00064_chunk140.WAV
# Saved chunk: R4_00064_chunk141.WAV
# Saved chunk: R4_00064_chunk142.WAV
# Saved chunk: R4_00064_chunk143.WAV
# Saved chunk: R4_00064_chunk144.WAV
# Saved chunk: R4_00064_chunk145.WAV
# Saved chunk: R4_00064_chunk146.WAV
# Saved chunk: R4_00064_chunk147.WAV
# Saved chunk: R4_00064_chunk148.WAV
# Saved chunk: R4_00064_chunk149.WAV
# Saved chunk: R4_00064_chunk150.WAV
# Saved chunk: R4_00064_chunk151.WAV
# Saved chunk: R4_00064_chunk152.WAV
# Saved chunk: R4_00064_chunk153.WAV
# Saved chunk: R4_00064_chunk154.WAV
# Saved chunk: R4_00064_chunk155.WAV
# Saved chunk: R4_00064_chunk156.WAV
# Saved chunk: R4_00064_chunk157.WAV
# Saved chunk: R4_00064_chunk158.WAV
# Saved chunk: R4_00064_chunk159.WAV
# Saved chunk: R4_00064_chunk160.WAV
# Saved chunk: R4_00064_chunk161.WAV
# Saved chunk: R4_00064_chunk162.WAV
# Saved chunk: R4_00064_chunk163.WAV
# Saved chunk: R4_00064_chunk164.WAV
# Saved chunk: R4_00064_chunk165.WAV
# Saved chunk: R4_00064_chunk166.WAV
# Saved chunk: R4_00064_chunk167.WAV
# Saved chunk: R4_00064_chunk168.WAV
# Saved chunk: R4_00064_chunk169.WAV
# Saved chunk: R4_00064_chunk170.WAV
# Saved chunk: R4_00064_chunk171.WAV
# Saved chunk: R4_00064_chunk172.WAV
# Saved chunk: R4_00064_chunk173.WAV
# Saved chunk: R4_00064_chunk174.WAV
# Saved chunk: R4_00064_chunk175.WAV
# Saved chunk: R4_00064_chunk176.WAV
# Saved chunk: R4_00064_chunk177.WAV
# Saved chunk: R4_00064_chunk178.WAV
# Saved chunk: R4_00064_chunk179.WAV
# Saved chunk: R4_00064_chunk180.WAV
# Saved chunk: R4_00064_chunk181.WAV
# Saved chunk: R4_00064_chunk182.WAV
# Saved chunk: R4_00064_chunk183.WAV
# Saved chunk: R4_00064_chunk184.WAV
# Saved chunk: R4_00064_chunk185.WAV
# Saved chunk: R4_00064_chunk186.WAV
# Saved chunk: R4_00064_chunk187.WAV
# Saved chunk: R4_00064_chunk188.WAV
# Saved chunk: R4_00064_chunk189.WAV
# Saved chunk: R4_00064_chunk190.WAV
# Saved chunk: R4_00064_chunk191.WAV
# Saved chunk: R4_00064_chunk192.WAV
# Saved chunk: R4_00064_chunk193.WAV
# Saved chunk: R4_00064_chunk194.WAV
# Saved chunk: R4_00064_chunk195.WAV
# Saved chunk: R4_00064_chunk196.WAV
# Saved chunk: R4_00064_chunk197.WAV
# Saved chunk: R4_00064_chunk198.WAV
# Saved chunk: R4_00064_chunk199.WAV
# Saved chunk: R4_00064_chunk200.WAV
# Saved chunk: R4_00064_chunk201.WAV
# Saved chunk: R4_00064_chunk202.WAV
# Saved chunk: R4_00064_chunk203.WAV
# Saved chunk: R4_00064_chunk204.WAV
# Saved chunk: R4_00064_chunk205.WAV
# Saved chunk: R4_00064_chunk206.WAV
# Saved chunk: R4_00064_chunk207.WAV
# Saved chunk: R4_00064_chunk208.WAV
# Saved chunk: R4_00064_chunk209.WAV
# Saved chunk: R4_00064_chunk210.WAV
# Saved chunk: R4_00064_chunk211.WAV
# Saved chunk: R4_00064_chunk212.WAV
# Saved chunk: R4_00064_chunk213.WAV
# Saved chunk: R4_00064_chunk214.WAV
# Saved chunk: R4_00064_chunk215.WAV
# Saved chunk: R4_00064_chunk216.WAV
# Saved chunk: R4_00064_chunk217.WAV
# Saved chunk: R4_00064_chunk218.WAV
# Saved chunk: R4_00064_chunk219.WAV
